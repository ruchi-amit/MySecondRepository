# %%
import pandas as pd

# %%
pd.read_excel('updatepasswordelock.xlsx')
# Out:
#     DEVICE TYPE              LOCK NO   IMEI NO      MOBILE NO  \
# 0    traQloc-10  IMZBE-0199,55706253  55706253  5754204924677
# 1    traQloc-10  IMZBE-0200,55699490  55699490  5754204938121
# 2    traQloc-10  IMZBE-0201,55765507  55765507  5754206288451
# 3    traQloc-10  IMZBE-0202,55695332  55695332  5754206288463
# 4    traQloc-10  IMZBE-0203,55717128  55717128  5754206288433
# ..          ...                  ...       ...            ...
# 197  traQloc-10  IMZBE-0396,55717300  55717300  5754206288427
# 198  traQloc-10  IMZBE-0397,51764821  51764821  5754206288480
# 199  traQloc-10  IMZBE-0398,53778536  53778536  5754206288378
# 200  traQloc-10  IMZBE-0399,53744678  53744678  5754206288380
# 201  traQloc-10  IMZBE-0400,55726061  55726061  5754206288529
#
#                   SIM NO
# 0    8991102205622668923
# 1    8991102205622695090
# 2    8991102205600090769
# 3    8991102205600090884
# 4    8991102205600090587
# ..                   ...
# 197  8991102205600090520
# ...
